# %% [markdown]
# # AL 6-9

# %% [markdown]
# ### 1) 문제 정의
#
# 문자열 탐색키의 해시 함수 계산

# %% [markdown]
# ### 2) 알고리즘 설명
#
# 해시 함수를 사용하여 문자열 키를 정수 해시값으로 변환하는 알고리즘

# %% [markdown]
# ### 3) 손으로 푼 예제
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 4) 코드 개요
#
# 3행 : 문자열 모든 문자에 대해
# 4행 : 그 문자의 아스키 코드 값을 sum에 더함

# %% [markdown]
# ### 5) 알고리즘 코드

# %%
def hashFn(key) :
    sum = 0
    for c in key  :
        sum = sum + ord(c)
    return sum % M

# %% [markdown]
# ### 6) 수행결과
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 7) 테스트 코드

# %%
# 테스트 코드
M = 13
keys = ["apple", "banana", "cherry", "date", "fig", "grape", "kiwi", "lemon", "mango"]
print("키\t\t해시값")
print("-------------------")
for key in keys:
    print(f"{key}\t\t{hashFn(key)}")
# Out:
# 키		해시값
# -------------------
# apple		10
# banana		11
# cherry		3
# date		11
# fig		11
# grape		7
# kiwi		7
# lemon		6
# mango		10

# %% [markdown]
# ### 8) 복잡도 분석
#
# 시간 복잡도 : O(n)
